# %%
import pandas as pd

# %%
user_log_1 = pd.read_csv('B:\PythonPratices\kaggle\liushi/user_log_split_1.csv')

# %%
user_log_1.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>msno</th>
#       <th>date</th>
#       <th>num_25</th>
#       <th>num_50</th>
#       <th>num_75</th>
#       <th>num_985</th>
#       <th>num_100</th>
#       <th>num_unq</th>
#       <th>total_secs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>rxIP2f2aN0rYNp+toI0Obt/N/FYQX8hcO1fTmmy2h34=</td>
#       <td>20150513</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>280.335</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
# ...

# %%
user_log_1.count()
# Out:
# Unnamed: 0    5000000
# msno          5000000
# date          5000000
# num_25        5000000
# num_50        5000000
# num_75        5000000
# num_985       5000000
# num_100       5000000
# num_unq       5000000
# total_secs    5000000
# dtype: int64

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import datetime
from collections import Counter

# %%
train = pd.read_csv("../middle_files/train_aft_process_3.csv")

# %%
train.shape
# Out:
# (992931, 19)

# %%
train.head()
# Out:
#    Unnamed: 0                                          msno  is_churn  \
# 0           0  iNV99F1Rml7EMndOeLI0Y/iek6aCj/Qp1Z4dZvR+sak=         0
# 1           1  FMvFGmTU2EFxJvA/KcEWSejnRLvaO0oLBndU2JIukfc=         0
# 2           2  dGhsx1jh7U9YLdxxhgU/P5wtqpCM6y2zjwxCI7VdB5k=         0
# 3           3  KNKap5imm053aRoXqYhXF26UdYn9YPG+cK1no/SZSI4=         0
# 4           4  sKg9tjtTJq8a/eiS8mZMDaliHtCybCHMY0WgRX/NVXw=         0
#
#    logs_count  city    bd  gender  registered_via  registration_init_time  \
# 0         0.0   1.0   0.0     0.0             7.0              20170215.0
# 1         0.0  13.0  20.0     1.0             3.0              20130323.0
# 2        13.0   1.0   0.0     0.0             7.0              20110701.0
# 3         3.0  22.0  28.0     1.0             7.0              20160518.0
# 4         0.0   1.0   0.0     0.0             7.0              20151010.0
#
#    expiration_date  trains_count        date  num_25  num_50  num_75  num_985  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992931 entries, 0 to 992930
# Data columns (total 19 columns):
# Unnamed: 0                992931 non-null int64
# msno                      992931 non-null object
# is_churn                  992931 non-null int64
# logs_count                992931 non-null float64
# city                      992931 non-null float64
# bd                        992931 non-null float64
# gender                    992931 non-null float64
# registered_via            992931 non-null float64
# registration_init_time    992931 non-null float64
# expiration_date           992931 non-null float64
# trains_count              992931 non-null int64
# date                      495678 non-null float64
# num_25                    495678 non-null float64
# num_50                    495678 non-null float64
# num_75                    495678 non-null float64
# num_985                   495678 non-null float64
# num_100                   495678 non-null float64
# ...

# %%
train_and_members = pd.read_csv("../middle_files/train_and_members.csv")

# %%
train_and_members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992931 entries, 0 to 992930
# Data columns (total 11 columns):
# msno                              992931 non-null object
# is_churn                          992931 non-null int64
# city                              992931 non-null object
# bd                                992931 non-null object
# gender                            992931 non-null object
# registered_via                    992931 non-null object
# registration_init_time            992931 non-null object
# expiration_date                   992931 non-null object
# registration_init_time_year       992931 non-null object
# registration_init_time_month      992931 non-null object
# registration_init_time_weekday    992931 non-null object
# dtypes: int64(1), object(10)
# memory usage: 83.3+ MB

# %%
train_and_members.shape
# Out:
# (992931, 11)

# %%
train_and_members.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36  female
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38    male
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27  female
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23  female
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27    male
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
gender = {'male':1, 'female':2}
train_and_members['gender'] = train_and_members['gender'].map(gender)

# %%
members = pd.read_csv('../data/members.csv')

# %%
test = pd.read_csv("../data/sample_submission_zero.csv")

# %%
test = pd.merge(left=test, right=members, how='left', on=['msno'])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970960 entries, 0 to 970959
# Data columns (total 8 columns):
# msno                      970960 non-null object
# is_churn                  970960 non-null int64
# city                      859688 non-null float64
# bd                        859688 non-null float64
# gender                    393333 non-null object
# registered_via            859688 non-null float64
# registration_init_time    859688 non-null float64
# expiration_date           859688 non-null float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 66.7+ MB

# %%
test.head()
# Out:
#                                            msno  is_churn  city    bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0   5.0  28.0    male
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0  13.0  20.0    male
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0  13.0  18.0    male
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0   1.0   0.0     NaN
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0  13.0  35.0  female
#
#    registered_via  registration_init_time  expiration_date
# 0             3.0              20131223.0       20170822.0
# 1             3.0              20131223.0       20170519.0
# 2             3.0              20131227.0       20170919.0
# 3             7.0              20140109.0       20160325.0
# 4             7.0              20140125.0       20180218.0

# %%
test.shape
# Out:
# (970960, 8)

# %%
test['city'] = test.city.apply(lambda x: int(x) if pd.notnull(x) else "NAN")
test['registered_via'] = test.registered_via.apply(
    lambda x: int(x) if pd.notnull(x) else "NAN"
    )
test['gender'] = test['gender'].fillna("NAN")
test['gender'] = test['gender'].map(gender)

# %%
test.head()
# Out:
#                                            msno  is_churn city    bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28.0     1.0
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20.0     1.0
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18.0     1.0
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0.0     NaN
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35.0     2.0
#
#   registered_via  registration_init_time  expiration_date
# 0              3              20131223.0       20170822.0
# 1              3              20131223.0       20170519.0
# 2              3              20131227.0       20170919.0
# 3              7              20140109.0       20160325.0
# 4              7              20140125.0       20180218.0

# %%
test['gender'] = test.gender.apply(lambda x: int(x) if pd.notnull(x) else "NAN")

# %%
test['bd'] = test.bd.apply(lambda x: int(x) if pd.notnull(x) else "NAN")

# %%
test['bd'] = test.bd.apply(lambda x: -99999 if float(x)<=1 else x )
test['bd'] = test.bd.apply(lambda x: -99999 if float(x)>=100 else x )

# %%
test['registration_init_time'] = test.registration_init_time.apply(lambda x: datetime.strptime(str(int(x)), "%Y%m%d").date() if pd.notnull(x) else "NAN" )
test['expiration_date'] = test.expiration_date.apply(lambda x: datetime.strptime(str(int(x)), "%Y%m%d").date() if pd.notnull(x) else "NAN")

# %%
test.head()
# Out:
#                                            msno  is_churn city  bd gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28      1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20      1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18      1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0    NAN
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35      2
#
#   registered_via registration_init_time expiration_date
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18

# %%
# test.to_csv("../middle_files/test_and_members.csv")
train_and_members.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36     2.0
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38     1.0
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27     2.0
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23     2.0
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27     1.0
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
train_and_members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992931 entries, 0 to 992930
# Data columns (total 11 columns):
# msno                              992931 non-null object
# is_churn                          992931 non-null int64
# city                              992931 non-null object
# bd                                992931 non-null object
# gender                            396057 non-null float64
# registered_via                    992931 non-null object
# registration_init_time            992931 non-null object
# expiration_date                   992931 non-null object
# registration_init_time_year       992931 non-null object
# registration_init_time_month      992931 non-null object
# registration_init_time_weekday    992931 non-null object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 83.3+ MB

# %%
train_and_members['gender'] = train_and_members['gender'].apply(lambda x:int(x) if pd.notnull(x) else 0)

# %%
train_and_members.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
train_and_members['gender'].value_counts()
# Out:
# 0    596874
# 1    208200
# 2    187857
# Name: gender, dtype: int64

# %%
train_and_members.to_csv("../middle_files/train_and_members_v2.csv")

# %%
test['registration_init_time_year'] = pd.DatetimeIndex(
    test['registration_init_time']
).year
test['registration_init_time_year'] = test.registration_init_time_year.apply(
    lambda x: int(x) if pd.notnull(x) else "NAN"
)

test['registration_init_time_month'] = pd.DatetimeIndex(
    test['registration_init_time']
).month
test['registration_init_time_month'] = test.registration_init_time_month.apply(
    lambda x: int(x) if pd.notnull(x) else "NAN"
)

test['registration_init_time_weekday'] = pd.DatetimeIndex(
    test['registration_init_time']
).weekday_name
test['registration_init_time_weekday'] = test.registration_init_time_weekday.apply(
    lambda x: str(x) if pd.notnull(x) else "NAN" 
)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970960 entries, 0 to 970959
# Data columns (total 11 columns):
# msno                              970960 non-null object
# is_churn                          970960 non-null int64
# city                              970960 non-null object
# bd                                970960 non-null object
# gender                            970960 non-null object
# registered_via                    970960 non-null object
# registration_init_time            970960 non-null object
# expiration_date                   970960 non-null object
# registration_init_time_year       970960 non-null object
# registration_init_time_month      970960 non-null object
# registration_init_time_weekday    970960 non-null object
# dtypes: int64(1), object(10)
# memory usage: 88.9+ MB

# %%
test.head()
# Out:
#                                            msno  is_churn city  bd gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28      1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20      1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18      1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0    NAN
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35      2
#
#   registered_via registration_init_time expiration_date  \
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2013                           12
# 1                        2013                           12
# ...

# %%
train_and_members.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
test['gender'] = test['gender'].apply(lambda x: 0 if x == "NAN" else x)

# %%
test.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28       1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20       1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18       1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0       0
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35       2
#
#   registered_via registration_init_time expiration_date  \
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2013                           12
# ...

# %%
test.to_csv("../middle_files/test_and_memebers_v2.csv")

# %%
test.shape
# Out:
# (970960, 11)

# %%
train_and_members.shape
# Out:
# (992931, 11)

# %%
train.shape
# Out:
# (992931, 19)

# %%
test_tmp = pd.read_csv("../data/sample_submission_zero.csv")

# %%
test_tmp.shape
# Out:
# (970960, 2)

# %%
del test_tmp

# %%
# %whos
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# Counter             type         <class 'collections.Counter'>
# datetime            type         <class 'datetime.datetime'>
# gender              dict         n=2
# members             DataFrame                             <...>5116194 rows x 7 columns]
# np                  module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd                  module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt                 module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns                 module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# test                DataFrame                             <...>970960 rows x 11 columns]
# time                module       <module 'time' (built-in)>
# train               DataFrame            Unnamed: 0       <...>992931 rows x 19 columns]
# ...

# %%
del training

# %%
transactions = pd.read_csv("../data/df_transactions.csv")

# %%
transactions.head()
# Out:
#    Unnamed: 0                                          msno  \
# 0           0  YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=
# 1           1  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=
# 2           2  UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=
# 3           3  M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=
# 4           4  yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=
#
#    payment_method_id  payment_plan_days  plan_list_price  actual_amount_paid  \
# 0                 41                 30              129                 129
# 1                 41                 30              149                 149
# 2                 41                 30              129                 129
# 3                 39                 30              149                 149
# 4                 39                 30              149                 149
#
#    is_auto_renew  transaction_date  membership_expire_date  is_cancel  \
# ...

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21547746 entries, 0 to 21547745
# Data columns (total 16 columns):
# Unnamed: 0                      int64
# msno                            object
# payment_method_id               int64
# payment_plan_days               int64
# plan_list_price                 int64
# actual_amount_paid              int64
# is_auto_renew                   int64
# transaction_date                int64
# membership_expire_date          int64
# is_cancel                       int64
# transaction_date_year           int64
# transaction_date_month          int64
# transaction_date_date           int64
# membership_expire_date_year     int64
# membership_expire_date_month    int64
# membership_expire_date_date     int64
# dtypes: int64(15), object(1)
# memory usage: 2.6+ GB

# %%
train_aft_process_3 = pd.read_csv("../middle_files/train_aft_process_3.csv")

# %%
train_aft_process_3.head()
# Out:
#    Unnamed: 0                                          msno  is_churn  \
# 0           0  iNV99F1Rml7EMndOeLI0Y/iek6aCj/Qp1Z4dZvR+sak=         0
# 1           1  FMvFGmTU2EFxJvA/KcEWSejnRLvaO0oLBndU2JIukfc=         0
# 2           2  dGhsx1jh7U9YLdxxhgU/P5wtqpCM6y2zjwxCI7VdB5k=         0
# 3           3  KNKap5imm053aRoXqYhXF26UdYn9YPG+cK1no/SZSI4=         0
# 4           4  sKg9tjtTJq8a/eiS8mZMDaliHtCybCHMY0WgRX/NVXw=         0
#
#    logs_count  city    bd  gender  registered_via  registration_init_time  \
# 0         0.0   1.0   0.0     0.0             7.0              20170215.0
# 1         0.0  13.0  20.0     1.0             3.0              20130323.0
# 2        13.0   1.0   0.0     0.0             7.0              20110701.0
# 3         3.0  22.0  28.0     1.0             7.0              20160518.0
# 4         0.0   1.0   0.0     0.0             7.0              20151010.0
#
#    expiration_date  trains_count        date  num_25  num_50  num_75  num_985  \
# ...

# %%
del train_aft_process_3

# %%
transactions_count = pd.DataFrame(transactions['msno'].value_counts().reset_index()) # 统计每个用户交易行为次数transactions['tran_count'] = 
transactions_count.columns = ['msno','trans_count']

# %%
training = train_and_members

# %%
# transactions_count.head()
transactions = transactions.drop('Unnamed: 0', axis=1)

# %%
training = pd.merge(training, transactions_count, on=['msno'], how='left')

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
testing = pd.merge(test, transactions_count, on=['msno'], how='left')

# %%
testing.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28       1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20       1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18       1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0       0
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35       2
#
#   registered_via registration_init_time expiration_date  \
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2013                           12
# ...

# %%
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 970960 entries, 0 to 970959
# Data columns (total 12 columns):
# msno                              970960 non-null object
# is_churn                          970960 non-null int64
# city                              970960 non-null object
# bd                                970960 non-null object
# gender                            970960 non-null int64
# registered_via                    970960 non-null object
# registration_init_time            970960 non-null object
# expiration_date                   970960 non-null object
# registration_init_time_year       970960 non-null object
# registration_init_time_month      970960 non-null object
# registration_init_time_weekday    970960 non-null object
# trans_count                       968433 non-null float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 96.3+ MB

# %%
# testing['trans_count'] = testing['trans_count'].astype(np.int64)
testing['trans_count'] = testing['trans_count'].apply(lambda x: int(x) if pd.notnull(x) else 0)

# %%
testing.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28       1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20       1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18       1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0       0
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35       2
#
#   registered_via registration_init_time expiration_date  \
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2013                           12
# ...

# %%
transactions.head()
# Out:
#                                            msno  payment_method_id  \
# 0  YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# 1  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 2  UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# 3  M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# 4  yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              129                 129              1
# 1                 30              149                 149              1
# 2                 30              129                 129              1
# 3                 30              149                 149              1
# 4                 30              149                 149              1
#
#    transaction_date  membership_expire_date  is_cancel  transaction_date_year  \
# ...

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
# chunk = pd.
# training = pd.merge(training, transactions, how='left', on=['msno'])
# transactions.to_csv('../middle_files/transactions_v2.csv', index=False)
transactions = pd.read_csv("../middle_files/transactions_v2.csv")

# %%
# 计划购买的总天数，计划总钱数，实际付款总钱数
transactions = pd.read_csv("../middle_files/transactions_v2.csv")
sum_payment_plan_days = pd.DataFrame(transactions.groupby(by=['msno'], as_index=False)['payment_plan_days'].sum())

# %%
sum_payment_plan_days.head()
# Out:
#                                            msno  payment_plan_days
# 0  +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=                  7
# 1  +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=                410
# 2  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                120
# 3  +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                543
# 4  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=                750

# %%
training = pd.read_csv("../middle_files/train_and_members_v2.csv")

# %%
training.head()
# Out:
#    Unnamed: 0                                          msno  is_churn city  \
# 0           0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18
# 1           1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10
# 2           2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11
# 3           3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13
# 4           4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3
#
#    bd  gender registered_via registration_init_time expiration_date  \
# 0  36       2              9             2005-04-06      2017-09-07
# 1  38       1              9             2005-04-07      2017-03-21
# 2  27       2              9             2005-10-16      2017-02-03
# 3  23       2              9             2005-11-02      2017-09-26
# 4  27       1              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# ...

# %%
training = training.drop(['Unnamed: 0'], axis=1)

# %%
training = pd.merge(training, transactions_count, on=['msno'], how='left')

# %%
transactions_count = pd.read_csv("../middle_files/transactions_aft_count.csv")

# %%
transactions_count = transactions_count.drop(['Unnamed: 0'], axis=1)

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
training.to_csv("../middle_files/traning_with_trans_count.csv", index=False)

# %%
training = pd.merge(training, sum_payment_plan_days, on=['msno'], how='left')

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
testing = pd.read_csv("../middle_files/test_and_memebers_v2.csv")

# %%
testing.head()
# Out:
#    Unnamed: 0                                          msno  is_churn city  \
# 0           0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5
# 1           1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13
# 2           2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13
# 3           3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1
# 4           4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13
#
#    bd  gender registered_via registration_init_time expiration_date  \
# 0  28       1              3             2013-12-23      2017-08-22
# 1  20       1              3             2013-12-23      2017-05-19
# 2  18       1              3             2013-12-27      2017-09-19
# 3   0       0              7             2014-01-09      2016-03-25
# 4  35       2              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# ...

# %%
testing = testing.drop(['Unnamed: 0'], axis=1)

# %%
testing = pd.merge(testing, transactions_count, on=['msno'], how='left')

# %%
testing['trans_count'] = testing['trans_count'].apply(lambda x: int(x) if pd.notnull(x) else 0)

# %%
testing.to_csv("../middle_files/testing_with_trans_count.csv", index=False)

# %%
sum_plan_list_price = pd.DataFrame(transactions.groupby(by=['msno'], as_index=False)['plan_list_price'].sum())

# %%
training = pd.merge(training, sum_plan_list_price, on=['msno'], how='left')

# %%
testing = pd.merge(testing, sum_plan_list_price, on=['msno'], how='left')

# %%
# %whos
# Out:
# Variable                Type         Data/Info
# ----------------------------------------------
# Counter                 type         <class 'collections.Counter'>
# datetime                type         <class 'datetime.datetime'>
# np                      module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd                      module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt                     module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# resu                    DataFrame                             <...>FvphY=                  7
# sns                     module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# sum_payment_plan_days   DataFrame                             <...>2363626 rows x 2 columns]
# sum_plan_list_price     DataFrame                             <...>2363626 rows x 2 columns]
# testing                 DataFrame                             <...>970960 rows x 13 columns]
# ...

# %%
sum_plan_list_price.to_csv("../middle_files/sum_plan_list_price.csv", index=False)

# %%
del sum_plan_list_price

# %%
del sum_payment_plan_days

# %%
sum_actual_amount_paid = pd.DataFrame(transactions.groupby(by=['msno'], as_index=False)['actual_amount_paid'].sum())

# %%
training = pd.merge(training, sum_actual_amount_paid, on=['msno'], how='left')

# %%
testing = pd.merge(testing, sum_actual_amount_paid, on=['msno'], how='left')

# %%
sum_actual_amount_paid.to_csv("../middle_files/sum_actual_amount_paid.csv", index=False)

# %%
del sum_actual_amount_paid

# %%
training.to_csv("../middle_files/traning_with_sum.csv",index=False)

# %%
testing.to_csv("../middle_files/testing.csv",index=False)

# %%
# %whos
# Out:
# Variable             Type         Data/Info
# -------------------------------------------
# Counter              type         <class 'collections.Counter'>
# datetime             type         <class 'datetime.datetime'>
# np                   module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd                   module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt                  module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# resu                 DataFrame                             <...>FvphY=                  7
# sns                  module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# testing              DataFrame                             <...>970960 rows x 14 columns]
# time                 module       <module 'time' (built-in)>
# training             DataFrame                             <...>992931 rows x 15 columns]
# ...

# %%
del transactions_count

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
columns = training.columns

# %%
columns
# Out:
# Index(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date',
#        'registration_init_time_year', 'registration_init_time_month',
#        'registration_init_time_weekday', 'trans_count', 'payment_plan_days',
#        'plan_list_price', 'actual_amount_paid'],
#       dtype='object')

# %%
cols = pd.Series(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
       'registration_init_time', 'expiration_date',
       'registration_init_time_year', 'registration_init_time_month',
       'registration_init_time_weekday', 'trans_count', 'payment_plan_days_sum',
       'plan_list_price_sum', 'actual_amount_paid_sum'])

# %%
training_v2 = training

# %%
training_v2.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
training = training_v2

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
training_v2.rename(
    columns={'payment_plan_days':'payment_plan_days_sum', 'plan_list_price': 'plan_list_price_all', 'actual_amount_paid' : 'actual_amount_paid_sum'},
    inplace=True
)

# %%
training_v2.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
testing.rename(
    columns={'payment_plan_days':'payment_plan_days_sum', 'plan_list_price': 'plan_list_price_all', 'actual_amount_paid' : 'actual_amount_paid_sum'},
    inplace=True
)

# %%
# training_v2 = pd.merge()
transactions.head()
# Out:
#                                            msno  payment_method_id  \
# 0  YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# 1  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 2  UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# 3  M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# 4  yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              129                 129              1
# 1                 30              149                 149              1
# 2                 30              129                 129              1
# 3                 30              149                 149              1
# 4                 30              149                 149              1
#
#    transaction_date  membership_expire_date  is_cancel  transaction_date_year  \
# ...

# %%
training = pd.read_csv("../middle_files/traning_with_sum.csv")
# training_v2 = pd.merge(training_v2, transactions, on=['msno'], how='left')

# %%
transactions = pd.read_csv("../data/df_transactions.csv")

# %%
transactions.head()
# Out:
#    Unnamed: 0                                          msno  \
# 0           0  YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=
# 1           1  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=
# 2           2  UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=
# 3           3  M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=
# 4           4  yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=
#
#    payment_method_id  payment_plan_days  plan_list_price  actual_amount_paid  \
# 0                 41                 30              129                 129
# 1                 41                 30              149                 149
# 2                 41                 30              129                 129
# 3                 39                 30              149                 149
# 4                 39                 30              149                 149
#
#    is_auto_renew  transaction_date  membership_expire_date  is_cancel  \
# ...

# %%
transactions = transactions.drop(['Unnamed: 0'], axis=1)

# %%
training = pd.merge(training, transactions, on=['msno'], how='left')

# %%
training.shape
# Out:
# (15883148, 29)

# %%
training.to_csv("../middle_files/traning_with_trans_count_and_transactions.csv", index=False)

# %%
# # training = training.drop_duplicates(['msno'])
# l = training['msno'].unique()
# # print('a')

# %%
training = pd.read_csv("../middle_files/traning_with_trans_count_and_transactions.csv")

# %%
training.shape
# Out:
# (15883148, 29)

# %%
trainings = training['msno'].unique()

# %%
trainings.shape
# Out:
# (992931,)

# %%
training_tmp =  training

# %%
training_tmp = training_tmp.drop_duplicates(['msno'])

# %%
training_tmp.shape
# Out:
# (992931, 29)

# %%
training_tmp.head()
# Out:
#                                             msno  is_churn city  bd  gender  \
# 0   waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 2   QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 25  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 35  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 37  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#    registered_via registration_init_time expiration_date  \
# 0               9             2005-04-06      2017-09-07
# 2               9             2005-04-07      2017-03-21
# 25              9             2005-10-16      2017-02-03
# 35              9             2005-11-02      2017-09-26
# 37              9             2005-12-28      2017-09-27
#
#    registration_init_time_year registration_init_time_month  \
# 0                         2005                            4
# ...

# %%
training_tmp.to_csv("../middle_files/traning_with_trans_count_and_transactions_drop_duplicates.csv", index=False)

# %%
# %whos
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# Counter        type         <class 'collections.Counter'>
# datetime       type         <class 'datetime.datetime'>
# np             module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd             module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt            module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns            module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# time           module       <module 'time' (built-in)>
# training       DataFrame                             <...>883148 rows x 29 columns]
# training_tmp   DataFrame                             <...>992931 rows x 29 columns]
# trainings      ndarray      992931: 992931 elems, type `object`, 7943448 bytes (7.575462341308594 Mb)

# %%
del training

# %%
del trainings

# %%
testing = pd.read_csv("../middle_files/testing_with_trans_count.csv")

# %%
testing.shape
# Out:
# (970960, 12)

# %%
del testing

# %%
testing = pd.read_csv("../middle_files/testing.csv")

# %%
testing.shape
# Out:
# (970960, 14)

# %%
testing.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28       1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20       1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18       1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0       0
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35       2
#
#   registered_via registration_init_time expiration_date  \
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2013                           12
# ...

# %%
# cols = [{'plan_list_price': 'plan_list_price_sum', 'actual_amount_paid': 'actual_amount_paid_sum', }]
transactions = pd.read_csv("../middle_files/transactions_v2.csv")
sum_payment_plan_days = pd.DataFrame(transactions.groupby(by=['msno'], as_index=False)['payment_plan_days'].sum())

# %%
training_tmp.columns
# Out:
# Index(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date',
#        'registration_init_time_year', 'registration_init_time_month',
#        'registration_init_time_weekday', 'trans_count', 'payment_plan_days_x',
#        'plan_list_price_x', 'actual_amount_paid_x', 'payment_method_id',
#        'payment_plan_days_y', 'plan_list_price_y', 'actual_amount_paid_y',
#        'is_auto_renew', 'transaction_date', 'membership_expire_date',
#        'is_cancel', 'transaction_date_year', 'transaction_date_month',
#        'transaction_date_date', 'membership_expire_date_year',
#        'membership_expire_date_month', 'membership_expire_date_date'],
#       dtype='object')

# %%
testing = pd.merge(testing, sum_payment_plan_days, on=['msno'], how='left')

# %%
testing.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28       1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20       1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18       1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0       0
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35       2
#
#   registered_via registration_init_time expiration_date  \
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2013                           12
# ...

# %%
testing.rename(
    columns={'payment_plan_days':'payment_plan_days_sum', 'plan_list_price': 'plan_list_price_sum', 'actual_amount_paid' : 'actual_amount_paid_sum'},
    inplace=True
)

# %%
testing.columns
# Out:
# Index(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date',
#        'registration_init_time_year', 'registration_init_time_month',
#        'registration_init_time_weekday', 'trans_count', 'plan_list_price_sum',
#        'actual_amount_paid_sum', 'payment_plan_days_sum'],
#       dtype='object')

# %%
testing.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         0    5  28       1
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         0   13  20       1
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         0   13  18       1
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         0    1   0       0
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         0   13  35       2
#
#   registered_via registration_init_time expiration_date  \
# 0              3             2013-12-23      2017-08-22
# 1              3             2013-12-23      2017-05-19
# 2              3             2013-12-27      2017-09-19
# 3              7             2014-01-09      2016-03-25
# 4              7             2014-01-25      2018-02-18
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2013                           12
# ...

# %%
testing.to_csv("../middle_files/testing_with_sum.csv", index=False)

# %%
# %whos
# Out:
# Variable                Type         Data/Info
# ----------------------------------------------
# Counter                 type         <class 'collections.Counter'>
# datetime                type         <class 'datetime.datetime'>
# np                      module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd                      module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt                     module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns                     module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# sum_payment_plan_days   DataFrame                             <...>2363626 rows x 2 columns]
# testing                 DataFrame                             <...>970960 rows x 15 columns]
# time                    module       <module 'time' (built-in)>
# training_tmp            DataFrame                             <...>992931 rows x 29 columns]
# ...

# %%
del sum_payment_plan_days

# %%
del testing

# %%
training_tmp.head()
# Out:
#                                             msno  is_churn city  bd  gender  \
# 0   waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 2   QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 25  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 35  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 37  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#    registered_via registration_init_time expiration_date  \
# 0               9             2005-04-06      2017-09-07
# 2               9             2005-04-07      2017-03-21
# 25              9             2005-10-16      2017-02-03
# 35              9             2005-11-02      2017-09-26
# 37              9             2005-12-28      2017-09-27
#
#    registration_init_time_year registration_init_time_month  \
# 0                         2005                            4
# ...

# %%
training_tmp.columns
# Out:
# Index(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date',
#        'registration_init_time_year', 'registration_init_time_month',
#        'registration_init_time_weekday', 'trans_count', 'payment_plan_days_x',
#        'plan_list_price_x', 'actual_amount_paid_x', 'payment_method_id',
#        'payment_plan_days_y', 'plan_list_price_y', 'actual_amount_paid_y',
#        'is_auto_renew', 'transaction_date', 'membership_expire_date',
#        'is_cancel', 'transaction_date_year', 'transaction_date_month',
#        'transaction_date_date', 'membership_expire_date_year',
#        'membership_expire_date_month', 'membership_expire_date_date'],
#       dtype='object')

# %%
del training_tmp

# %%
training = pd.read_csv("../middle_files/traning_with_sum.csv")

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
training.rename(
    columns={'payment_plan_days':'payment_plan_days_sum', 'plan_list_price': 'plan_list_price_sum', 'actual_amount_paid' : 'actual_amount_paid_sum'},
    inplace=True
)

# %%
training.columns
# Out:
# Index(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date',
#        'registration_init_time_year', 'registration_init_time_month',
#        'registration_init_time_weekday', 'trans_count',
#        'payment_plan_days_sum', 'plan_list_price_sum',
#        'actual_amount_paid_sum'],
#       dtype='object')

# %%
training.shape
# Out:
# (992931, 15)

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
training.to_csv("../middle_files/training_with_sum_v2.csv",index=False)

# %%
# %whos
# Out:
# Variable                 Type         Data/Info
# -----------------------------------------------
# Counter                  type         <class 'collections.Counter'>
# datetime                 type         <class 'datetime.datetime'>
# np                       module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd                       module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt                      module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns                      module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# sum_actual_amount_paid   DataFrame                             <...>2363626 rows x 2 columns]
# time                     module       <module 'time' (built-in)>
# training                 DataFrame                             <...>992931 rows x 15 columns]
# transactions             DataFrame                             <...>547746 rows x 15 columns]

# %%
del sum_actual_amount_paid

# %%
training_tmp = training

# %%
training_tmp = pd.merge(training_tmp, transactions, on=['msno'], how='left')

# %%
training_tmp.shape
# Out:
# (15883148, 29)

# %%
training_tmp.columns
# Out:
# Index(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date',
#        'registration_init_time_year', 'registration_init_time_month',
#        'registration_init_time_weekday', 'trans_count',
#        'payment_plan_days_sum', 'plan_list_price_sum',
#        'actual_amount_paid_sum', 'payment_method_id', 'payment_plan_days',
#        'plan_list_price', 'actual_amount_paid', 'is_auto_renew',
#        'transaction_date', 'membership_expire_date', 'is_cancel',
#        'transaction_date_year', 'transaction_date_month',
#        'transaction_date_date', 'membership_expire_date_year',
#        'membership_expire_date_month', 'membership_expire_date_date'],
#       dtype='object')

# %%
training_tmp = training_tmp.drop_duplicates(['msno'])

# %%
training_tmp.shape
# Out:
# (992931, 29)

# %%
training_tmp.to_csv("../middle_files/traning_with_trans_count_and_transactions_drop_duplicates_v2.csv")

# %%
# %whos
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# Counter        type         <class 'collections.Counter'>
# datetime       type         <class 'datetime.datetime'>
# np             module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd             module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt            module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns            module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# time           module       <module 'time' (built-in)>
# training       DataFrame                             <...>992931 rows x 15 columns]
# training_tmp   DataFrame                             <...>992931 rows x 29 columns]
# transactions   DataFrame                             <...>547746 rows x 15 columns]

# %%
del training

# %%
testing = pd.read_csv("../middle_files/testing_with_sum.csv")

# %%
testing.shape
# Out:
# (970960, 15)

# %%
testing = pd.merge(testing,transactions, on=['msno'], how='left')

# %%
testing.shape
# Out:
# (15126113, 29)

# %%
# testing = testing.drop_duplicates(['msno'])
# %whos
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# Counter        type         <class 'collections.Counter'>
# datetime       type         <class 'datetime.datetime'>
# np             module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd             module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt            module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns            module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# testing        DataFrame    <object with id 1540002306480 (str() failed)>
# time           module       <module 'time' (built-in)>
# training_tmp   DataFrame                             <...>992931 rows x 29 columns]
# transactions   DataFrame                             <...>547746 rows x 15 columns]

# %%
testing.shape
# Out:
# (15126113, 29)

# %%
testing = testing.to_csv("../middle_files/testing_with_sum_and_transactions.csv", index=False)

# %%
testing = pd.read_csv("../middle_files/testing_with_sum_and_transactions.csv")

# %%
testing.shape
# Out:
# (15126113, 29)

# %%
testing = testing.drop_duplicates(['msno'])

# %%
testing.shape
# Out:
# (970960, 29)

# %%
testing.to_csv("../middle_files/testing_with_sum_and_transactions_drop_dup.csv")

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# Counter    type         <class 'collections.Counter'>
# datetime   type         <class 'datetime.datetime'>
# np         module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd         module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# plt        module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns        module       <module 'seaborn' from 'E<...>s\\seaborn\\__init__.py'>
# testing    DataFrame                             <...>970960 rows x 29 columns]
# time       module       <module 'time' (built-in)>

# %%
training = pd.read_csv("../middle_files/traning_with_trans_count_and_transactions_drop_duplicates.csv")

# %%
training.shape
# Out:
# (992931, 29)

# %%
training.head()
# Out:
#                                            msno  is_churn city  bd  gender  \
# 0  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=         1   18  36       2
# 1  QA7uiXy8vIbUSPOkCf9RwQ3FsT8jVq2OxDr8zqa7bRQ=         1   10  38       1
# 2  fGwBva6hikQmTJzrbz/2Ezjm5Cth5jZUNvXigKK2AFA=         1   11  27       2
# 3  mT5V8rEpa+8wuqi6x0DoVd3H5icMKkE9Prt49UlmK+4=         1   13  23       2
# 4  XaPhtGLk/5UvvOYHcONTwsnH97P4eGECeq+BARGItRw=         1    3  27       1
#
#   registered_via registration_init_time expiration_date  \
# 0              9             2005-04-06      2017-09-07
# 1              9             2005-04-07      2017-03-21
# 2              9             2005-10-16      2017-02-03
# 3              9             2005-11-02      2017-09-26
# 4              9             2005-12-28      2017-09-27
#
#   registration_init_time_year registration_init_time_month  \
# 0                        2005                            4
# ...

# %%
user_log1 = pd.read_csv("../data2/user_log_split_v2_12.csv")

# %%
user_log1.shape
# Out:
# (5000000, 10)

# %%
user_log1.head()
# Out:
#    Unnamed: 0                                          msno      date  num_25  \
# 0           0  mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=  20160211      45
# 1           1  mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=  20160521       4
# 2           2  mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=  20160811       4
# 3           3  mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=  20161008       2
# 4           4  mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=  20161204      41
#
#    num_50  num_75  num_985  num_100  num_unq  total_secs
# 0       3       1        2       34       65    2.763741
# 1       0       0        0        9       13    0.632839
# 2       1       3        1       40       44    3.055915
# 3       2       1        2       21        9    1.991698
# 4       2       3        1       43       67    3.223290

# %%
user_log1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 10 columns):
# Unnamed: 0    int64
# msno          object
# date          int64
# num_25        int64
# num_50        int64
# num_75        int64
# num_985       int64
# num_100       int64
# num_unq       int64
# total_secs    float64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 381.5+ MB

# %%
user_log2 = pd.read_csv("../data/user_log_split_1.csv")

# %%
user_log2.shape
# Out:
# (5000000, 10)

# %%
user_log2.head()
# Out:
#    Unnamed: 0                                          msno      date  num_25  \
# 0           0  rxIP2f2aN0rYNp+toI0Obt/N/FYQX8hcO1fTmmy2h34=  20150513       0
# 1           1  rxIP2f2aN0rYNp+toI0Obt/N/FYQX8hcO1fTmmy2h34=  20150709       9
# 2           2  yxiEWwE9VR5utpUecLxVdQ5B7NysUPfrNtGINaM2zA8=  20150105       3
# 3           3  yxiEWwE9VR5utpUecLxVdQ5B7NysUPfrNtGINaM2zA8=  20150306       1
# 4           4  yxiEWwE9VR5utpUecLxVdQ5B7NysUPfrNtGINaM2zA8=  20150501       3
#
#    num_50  num_75  num_985  num_100  num_unq  total_secs
# 0       0       0        0        1        1     280.335
# 1       1       0        0        7       11    1658.948
# 2       3       0        0       68       36   17364.956
# 3       0       1        1       97       27   24667.317
# 4       0       0        0       38       38    9649.029

# %%
user_log2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 10 columns):
# Unnamed: 0    int64
# msno          object
# date          int64
# num_25        int64
# num_50        int64
# num_75        int64
# num_985       int64
# num_100       int64
# num_unq       int64
# total_secs    float64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 381.5+ MB

# %%
userLog_3 = pd.concat([user_log1['msno'], user_log2['msno']], ignore_index=True)

# %%
userLog_3.shape
# Out:
# (10000000,)

# %%
userLog_3.head()
# Out:
# 0    mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=
# 1    mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=
# 2    mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=
# 3    mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=
# 4    mzvqKw0nhex7xVfIq4ZGQ5cSdRLvi0E5/fxGy0XtraY=
# Name: msno, dtype: object

# %%
user_log1 = user_log2

# %%
del user_log2

# %%
del userLog_3

# %%
user_log1.shape
# Out:
# (5000000, 10)

# %%
userLog_count = pd.DataFrame(user_log1['msno'])
for i in range(2, 80):
    user_log_tmp = pd.read_csv("../data2/user_log_split_v2_" + str(i) + ".csv")
    user_log_tmp = pd.DataFrame(user_log_tmp['msno'].value_counts().reset_index()) # 统计每个用户日志行为次数
    user_log_tmp.columns = ['msno','logs_count']
    userLog_count = pd.concat([userLog_count, user_log_tmp], ignore_index=True)
    user_log_tmp= []
    print("file shape: ", userLog_count.shape)
    print(str(i) + "file merge success!")
# Out:
# file shape:  (10000000, 2)
# 2file merge success!
# E:\anacoda\lib\site-packages\pandas\core\indexes\api.py:77: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
# file shape:  (15000000, 2)
# 3file merge success!
# file shape:  (20000000, 2)
# 4file merge success!
# file shape:  (25000000, 2)
# 5file merge success!
# file shape:  (30000000, 2)
# 6file merge success!
# file shape:  (35000000, 2)
# 7file merge success!
# file shape:  (40000000, 2)
# 8file merge success!
# file shape:  (45000000, 2)
# 9file merge success!
# file shape:  (50000000, 2)
# 10file merge success!
# file shape:  (55000000, 2)
# 11file merge success!
# file shape:  (60000000, 2)
# 12file merge success!
# file shape:  (65000000, 2)
# 13file merge success!
# file shape:  (70000000, 2)
# 14file merge success!
# file shape:  (75000000, 2)
# 15file merge success!
# file shape:  (80000000, 2)
# ...

# %%
userLog_count.shape
# Out:
# (225000000, 2)
